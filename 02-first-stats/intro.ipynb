# %% [markdown]
# # First Simulations, Visualizations, and Statistical Tests
#
#
#
# ```{image} figs/coins-flipping.png
# :alt: ML Generated Image of Coins Flipping in Front of a Computer Monitor
# :class: bg-primary mb-1
# :width: 250px
# :align: center
# ```
# *(Image generated by DALL E 2: (Image generated by DALL E 2: https://labs.openai.com/s/U6JQavoBLMmfeHOyJnkGlXQa)*

# %% [markdown]
# This page links to interactive elements for Chapter 2 of *Foundations of Data Science with Python*
#
# Interactive elements:
# * {doc}`Section 2.1: Motivating Problem: Is This Coin Fair?<1-motivating-problem>` (interactive flashcard)
# * {doc}`Section 2.2: First Computer Simulations<2-first-sims>` (interactive quiz)
# * {doc}`Section 2.3: First Visualizations: Scatter Plots and Histograms<3-first-vis>` (interactive quiz and flashcards)
# * {doc}`Section 2.4: First Statistical Tests<4-first-stats>` (interactive quiz)
# * {doc}`Section 2.5: Summary<5-summary>` (interactive quiz and flashcards)
