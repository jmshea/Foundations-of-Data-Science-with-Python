# %% [markdown]
# # Null Hypothesis Tests

# %% [markdown]
# ```{image} figs/grad-money.png
# :alt: DALL E 2 generated image of blue graduation mortar-board cap with orange tassel on top of money. Brown-covered book is in lower left corner
# :class: bg-primary mb-1
# :width: 300px
# :align: left
# ```
# *(Image generated by DALL E 2: https://labs.openai.com/s/5ouZEqmaSJ3HXuUSl9o7yd4f)*

# %% [markdown]
# This page links to interactive elements for Chapter 5 of *Foundations of Data Science with Python*
#
# Interactive elements:
#
# * {doc}`Section 5.1: Statistical Studies<1-statistical-studies>` (interactive flashcards)
# * {doc}`Section 5.2: General Resampling Approaches for Null Hypothesis Significance Testing<2-nhst>` (interactive flashcards)
# * {doc}`Section 5.3: Calculating $p$-Values<3-calculating-p-values>` (interactive flashcards)
# * {doc}`Section 5.4: How to Sample from the Pooled Data<4-how-to-sample>` (interactive flashcards)
# * {doc}`Section 5.6: Bootstrap Distribution and Confidence Intervals<6-bootstrap-dist-confidence-intervals>` (interactive flashcards)
# * {doc}`Section 5.7: Types of Errors and Statistical Power<7-errors-and-power>` (interactive flashcards)
# * {doc}`Section 5.8: Chapter Summary<8-summary>` (interactive flashcards -- quizzes coming soon)
